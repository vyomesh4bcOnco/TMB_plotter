# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os as os

# %%
input_df_path  = "C:/Users/prksh/Downloads/RegressionModels/Plots/Plots/TMB_plotter v2/input.csv"

# %%
pd.read_csv(input_df_path)
# Out:
#     Sample Name                         Broad Category Cancer Type  TMB Score
# 0   IN-423-VARC                                      Adrenal gland       2.80
# 1           AB2                                              Brain       3.30
# 2           AB3                                             Breast       5.60
# 3           AB4                                             Cervix       1.90
# 4           AB5                                         Colorectal       4.50
# 5           AB6                                        Endometrium       5.30
# 6           AB7                                          Esophagus       3.70
# 7           AB8                                      Hepatobiliary       5.00
# 8           AB9                                   Intestinal tract       4.70
# 9          AB10                                        Head & neck       2.20
# 10         AB11                                               Lung       3.40
# ...

# %%
os.chdir('C:/Users/prksh/Downloads/RegressionModels/Plots/Plots/TMB_plotter v2/')

# %%
bkg_data = pd.read_csv('distribution.csv')
bkg_data
# Out:
#      Broad Category Cancer Type  TMB Score
# 0                 Adrenal gland       5.91
# 1                 Adrenal gland       1.06
# 2                 Adrenal gland       6.59
# 3                 Adrenal gland       9.04
# 4                 Adrenal gland      17.47
# ...                         ...        ...
# 1430                    Stomach      12.65
# 1431                    Stomach      19.50
# 1432                    Stomach      37.41
# 1433                    Stomach      37.41
# 1434                    Stomach      44.09
#
# [1435 rows x 2 columns]

# %%
sns.kdeplot(bkg_data['TMB Score'], cut=0, fill=True)
sns.kdeplot(bkg_data[bkg_data['Broad Category Cancer Type']=='Adrenal gland']['TMB Score'], cut=0, fill=True)
plt.axvline(20)
plt.text(-20, -0.07, '**The clinical outcomes of patients with cancer can vary significantly\nacross different geographies, highlighting the complexity of utilizing\nTMB as a predictive immunotherapy biomarker.\n**It is important to recognize that assuming a universal criterion and\ncutoff for all ethnicities and geographical areas may have adverse effects\non cancer patients. Therefore, caution should be exercised when interpreting\nTMB data, considering the diverse factors that influence its efficacy as a\nbiomarker in clinical settings.', ha='left')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a DataFrame called 'df'
df = pd.DataFrame({
    'x': [1, 2, 3],
    'y': [4, 5, 6]
})

# Create a scatterplot
ax = sns.scatterplot(x='x', y='y', data=df)

# Add text to the plot
ax.text(0.8, 2.5, '**The clinical outcomes of patients with cancer can vary significantly\nacross different geographies, highlighting the complexity of utilizing\nTMB as a predictive immunotherapy biomarker.\n**It is important to recognize that assuming a universal criterion and\ncutoff for all ethnicities and geographical areas may have adverse effects\non cancer patients. Therefore, caution should be exercised when interpreting\nTMB data, considering the diverse factors that influence its efficacy as a\nbiomarker in clinical settings.', ha='left')

plt.show()

# %%
len(df)
# Out:
# 3

# %%
import time
import sys

def loading_loop():
    chars = ['|', '/', '-', '\\']
    for _ in range(50):
        for char in chars:
            sys.stdout.write(f'Processing... {char}\r')
            sys.stdout.flush()
            time.sleep(0.1)

    print("\nProcess completed.")

# Call the loading loop function
loading_loop()
# Out:
# Processing... \
# Process completed.
